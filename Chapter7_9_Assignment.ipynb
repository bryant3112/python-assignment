# %%
things = ["mozzarella", "cinderella", "salmonella"]
print(things)

# %%
things[1] = things[1].capitalize()
print(things)

# %%
Yes, it changed the element in the list because we replaced "cinderella" with "Cinderella".

# %%
things[0] = things[0].upper()
print(things)

# %%
del things[2]
print(things)

# %%
The disease element "salmonella" was removed from the list.

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']

print(good())

# %%
def get_odds():
    for number in range(10):
        if number % 2 == 1:
            yield number

# Find the third odd number
count = 0

for num in get_odds():
    count += 1
    if count == 3:
        print(num)
        break
